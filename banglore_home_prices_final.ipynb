# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import matplotlib
matplotlib.rcParams['figure.figsize'] = [20,10]

# %%
df1 = pd.read_csv("bengaluru_house_prices.csv")
df1
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
df1.shape
# Out:
# (13320, 9)

# %%
g1 = df1.groupby('area_type')['area_type'].agg('count')

# %%
g1
# Out:
# area_type
# Built-up  Area          2418
# Carpet  Area              87
# Plot  Area              2025
# Super built-up  Area    8790
# Name: area_type, dtype: int64

# %%
df2 = df1.drop(['society','availability',],axis = 'columns')
df2
# Out:
#                   area_type                  location       size total_sqft  \
# 0      Super built-up  Area  Electronic City Phase II      2 BHK       1056
# 1                Plot  Area          Chikka Tirupathi  4 Bedroom       2600
# 2            Built-up  Area               Uttarahalli      3 BHK       1440
# 3      Super built-up  Area        Lingadheeranahalli      3 BHK       1521
# 4      Super built-up  Area                  Kothanur      2 BHK       1200
# ...                     ...                       ...        ...        ...
# 13315        Built-up  Area                Whitefield  5 Bedroom       3453
# 13316  Super built-up  Area             Richards Town      4 BHK       3600
# 13317        Built-up  Area     Raja Rajeshwari Nagar      2 BHK       1141
# 13318  Super built-up  Area           Padmanabhanagar      4 BHK       4689
# 13319  Super built-up  Area              Doddathoguru      1 BHK        550
#
#        bath  balcony   price
# ...

# %%
df2.isnull().sum()
# Out:
# area_type       0
# location        1
# size           16
# total_sqft      0
# bath           73
# balcony       609
# price           0
# dtype: int64

# %%
df3 = df2.dropna()
df3
# Out:
#                   area_type                  location       size total_sqft  \
# 0      Super built-up  Area  Electronic City Phase II      2 BHK       1056
# 1                Plot  Area          Chikka Tirupathi  4 Bedroom       2600
# 2            Built-up  Area               Uttarahalli      3 BHK       1440
# 3      Super built-up  Area        Lingadheeranahalli      3 BHK       1521
# 4      Super built-up  Area                  Kothanur      2 BHK       1200
# ...                     ...                       ...        ...        ...
# 13314  Super built-up  Area         Green Glen Layout      3 BHK       1715
# 13315        Built-up  Area                Whitefield  5 Bedroom       3453
# 13317        Built-up  Area     Raja Rajeshwari Nagar      2 BHK       1141
# 13318  Super built-up  Area           Padmanabhanagar      4 BHK       4689
# 13319  Super built-up  Area              Doddathoguru      1 BHK        550
#
#        bath  balcony   price
# ...

# %%
df3.isnull().sum()
# Out:
# area_type     0
# location      0
# size          0
# total_sqft    0
# bath          0
# balcony       0
# price         0
# dtype: int64

# %%
df3.shape
# Out:
# (12710, 7)

# %%
df3['size'].unique()
# Out:
# array(['2 BHK', '4 Bedroom', '3 BHK', '3 Bedroom', '1 BHK', '1 RK',
#        '4 BHK', '1 Bedroom', '2 Bedroom', '6 Bedroom', '8 Bedroom',
#        '7 Bedroom', '5 BHK', '7 BHK', '6 BHK', '5 Bedroom', '11 BHK',
#        '9 BHK', '9 Bedroom', '27 BHK', '11 Bedroom', '43 Bedroom',
#        '14 BHK', '8 BHK', '12 Bedroom', '10 Bedroom', '13 BHK'],
#       dtype=object)

# %%
df3['BHK'] = df3['size'].apply(lambda x: int(x.split(' ')[0]))
# Out:
# C:\Users\disha\AppData\Local\Temp/ipykernel_5008/3303903377.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['BHK'] = df3['size'].apply(lambda x: int(x.split(' ')[0]))

# %%
df3
# Out:
#                   area_type                  location       size total_sqft  \
# 0      Super built-up  Area  Electronic City Phase II      2 BHK       1056
# 1                Plot  Area          Chikka Tirupathi  4 Bedroom       2600
# 2            Built-up  Area               Uttarahalli      3 BHK       1440
# 3      Super built-up  Area        Lingadheeranahalli      3 BHK       1521
# 4      Super built-up  Area                  Kothanur      2 BHK       1200
# ...                     ...                       ...        ...        ...
# 13314  Super built-up  Area         Green Glen Layout      3 BHK       1715
# 13315        Built-up  Area                Whitefield  5 Bedroom       3453
# 13317        Built-up  Area     Raja Rajeshwari Nagar      2 BHK       1141
# 13318  Super built-up  Area           Padmanabhanagar      4 BHK       4689
# 13319  Super built-up  Area              Doddathoguru      1 BHK        550
#
#        bath  balcony   price  BHK
# ...

# %%
df3['BHK'].unique()
# Out:
# array([ 2,  4,  3,  1,  6,  8,  7,  5, 11,  9, 27, 43, 14, 12, 10, 13],
#       dtype=int64)

# %%
df3[df3.BHK>20]
# Out:
#                  area_type                   location        size total_sqft  \
# 1718  Super built-up  Area  2Electronic City Phase II      27 BHK       8000
# 4684            Plot  Area                Munnekollal  43 Bedroom       2400
#
#       bath  balcony  price  BHK
# 1718  27.0      0.0  230.0   27
# 4684  40.0      0.0  660.0   43

# %%
def is_float(x):
    try:
        float(x)
    except:
        return False
    return True

# %%
df3[~df3['total_sqft'].apply(is_float)].head(20)
# Out:
#                  area_type               location       size      total_sqft  \
# 30    Super built-up  Area              Yelahanka      4 BHK     2100 - 2850
# 122   Super built-up  Area                 Hebbal      4 BHK     3067 - 8156
# 137   Super built-up  Area     8th Phase JP Nagar      2 BHK     1042 - 1105
# 165   Super built-up  Area               Sarjapur      2 BHK     1145 - 1340
# 188   Super built-up  Area               KR Puram      2 BHK     1015 - 1540
# 410   Super built-up  Area                Kengeri      1 BHK  34.46Sq. Meter
# 549   Super built-up  Area            Hennur Road      2 BHK     1195 - 1440
# 661   Super built-up  Area              Yelahanka      2 BHK     1120 - 1145
# 672         Built-up  Area           Bettahalsoor  4 Bedroom     3090 - 5002
# 772   Super built-up  Area  Banashankari Stage VI      2 BHK     1160 - 1195
# 775         Built-up  Area           Basavanagara      1 BHK   1000Sq. Meter
# ...

# %%
def convert_sqft_to_num(x):
    tokens = x.split('-')
    if len(tokens) == 2:
        return (float(tokens[0])+float(tokens[1]))/2
    try:
        return float(x)
    except:
        return None

# %%
convert_sqft_to_num('1015 - 1540')
# Out:
# 1277.5

# %%
df4 = df3.copy()
df4.total_sqft = df4.total_sqft.apply(convert_sqft_to_num)
df4
# Out:
#                   area_type                  location       size  total_sqft  \
# 0      Super built-up  Area  Electronic City Phase II      2 BHK      1056.0
# 1                Plot  Area          Chikka Tirupathi  4 Bedroom      2600.0
# 2            Built-up  Area               Uttarahalli      3 BHK      1440.0
# 3      Super built-up  Area        Lingadheeranahalli      3 BHK      1521.0
# 4      Super built-up  Area                  Kothanur      2 BHK      1200.0
# ...                     ...                       ...        ...         ...
# 13314  Super built-up  Area         Green Glen Layout      3 BHK      1715.0
# 13315        Built-up  Area                Whitefield  5 Bedroom      3453.0
# 13317        Built-up  Area     Raja Rajeshwari Nagar      2 BHK      1141.0
# 13318  Super built-up  Area           Padmanabhanagar      4 BHK      4689.0
# 13319  Super built-up  Area              Doddathoguru      1 BHK       550.0
#
#        bath  balcony   price  BHK
# ...

# %%
df4.loc[30]
# Out:
# area_type     Super built-up  Area
# location                 Yelahanka
# size                         4 BHK
# total_sqft                  2475.0
# bath                           4.0
# balcony                        0.0
# price                        186.0
# BHK                              4
# Name: 30, dtype: object

# %%
df5 = df4.copy()
df5['price_per_sqft'] = df5['price']*100000/df5['total_sqft']
df5.head()
# Out:
#               area_type                  location       size  total_sqft  \
# 0  Super built-up  Area  Electronic City Phase II      2 BHK      1056.0
# 1            Plot  Area          Chikka Tirupathi  4 Bedroom      2600.0
# 2        Built-up  Area               Uttarahalli      3 BHK      1440.0
# 3  Super built-up  Area        Lingadheeranahalli      3 BHK      1521.0
# 4  Super built-up  Area                  Kothanur      2 BHK      1200.0
#
#    bath  balcony   price  BHK  price_per_sqft
# 0   2.0      1.0   39.07    2     3699.810606
# 1   5.0      3.0  120.00    4     4615.384615
# 2   2.0      3.0   62.00    3     4305.555556
# 3   3.0      1.0   95.00    3     6245.890861
# 4   2.0      1.0   51.00    2     4250.000000

# %%
df5['area_type'].unique()
# Out:
# array(['Super built-up  Area', 'Plot  Area', 'Built-up  Area',
#        'Carpet  Area'], dtype=object)

# %%
df5.location.unique()
# Out:
# array(['Electronic City Phase II', 'Chikka Tirupathi', 'Uttarahalli', ...,
#        '12th cross srinivas nagar banshankari 3rd stage',
#        'Havanur extension', 'Abshot Layout'], dtype=object)

# %%
len(df5.location.unique())
# Out:
# 1265

# %%
location_stats = df5['location'].value_counts(ascending=False)

# %%
location_stats
# Out:
# Whitefield            514
# Sarjapur  Road        372
# Electronic City       300
# Kanakpura Road        261
# Thanisandra           231
#                      ...
# Milk Colony             1
# Sundara Nagar           1
# Jaladarsini Layout      1
# Madanayakahalli         1
# Abshot Layout           1
# Name: location, Length: 1265, dtype: int64

# %%
location_stats.sum()
# Out:
# 12710

# %%
len(location_stats[location_stats<10])
# Out:
# 1018

# %%
location_stats_less_than_10 = location_stats[location_stats<=10]
location_stats_less_than_10
# Out:
# Kalkere               10
# Gunjur Palya          10
# Naganathapura         10
# HAL 2nd Stage         10
# Ganga Nagar           10
#                       ..
# Milk Colony            1
# Sundara Nagar          1
# Jaladarsini Layout     1
# Madanayakahalli        1
# Abshot Layout          1
# Name: location, Length: 1028, dtype: int64

# %%
df5.location = df5.location.apply(lambda x : 'other' if x in location_stats_less_than_10 else x)
df5
# Out:
#                   area_type                  location       size  total_sqft  \
# 0      Super built-up  Area  Electronic City Phase II      2 BHK      1056.0
# 1                Plot  Area          Chikka Tirupathi  4 Bedroom      2600.0
# 2            Built-up  Area               Uttarahalli      3 BHK      1440.0
# 3      Super built-up  Area        Lingadheeranahalli      3 BHK      1521.0
# 4      Super built-up  Area                  Kothanur      2 BHK      1200.0
# ...                     ...                       ...        ...         ...
# 13314  Super built-up  Area         Green Glen Layout      3 BHK      1715.0
# 13315        Built-up  Area                Whitefield  5 Bedroom      3453.0
# 13317        Built-up  Area     Raja Rajeshwari Nagar      2 BHK      1141.0
# 13318  Super built-up  Area           Padmanabhanagar      4 BHK      4689.0
# 13319  Super built-up  Area              Doddathoguru      1 BHK       550.0
#
# ...

# %%
df5[(df5.total_sqft/df5.BHK)<300]
# Out:
#             area_type          location       size  total_sqft  bath  balcony  \
# 58         Plot  Area     Murugeshpalya  6 Bedroom      1407.0   4.0      1.0
# 68         Plot  Area             other  8 Bedroom      1350.0   7.0      0.0
# 70         Plot  Area             other  3 Bedroom       500.0   3.0      2.0
# 78     Built-up  Area  Kaval Byrasandra      2 BHK       460.0   1.0      0.0
# 89         Plot  Area      Rajaji Nagar  6 Bedroom       710.0   6.0      3.0
# ...               ...               ...        ...         ...   ...      ...
# 13219      Plot  Area           Laggere  7 Bedroom      1590.0   9.0      3.0
# 13221      Plot  Area             other  9 Bedroom      1178.0   9.0      1.0
# 13281      Plot  Area   Margondanahalli  5 Bedroom      1375.0   5.0      1.0
# 13303      Plot  Area    Vidyaranyapura  5 Bedroom       774.0   5.0      3.0
# 13311      Plot  Area  Ramamurthy Nagar  7 Bedroom      1500.0   9.0      2.0
#
# ...

# %%
df5.shape
# Out:
# (12710, 9)

# %%
df6 = df5[~(df5.total_sqft/df5.BHK<300)]

# %%
df6.shape
# Out:
# (12055, 9)

# %%
df6
# Out:
#                   area_type                  location       size  total_sqft  \
# 0      Super built-up  Area  Electronic City Phase II      2 BHK      1056.0
# 1                Plot  Area          Chikka Tirupathi  4 Bedroom      2600.0
# 2            Built-up  Area               Uttarahalli      3 BHK      1440.0
# 3      Super built-up  Area        Lingadheeranahalli      3 BHK      1521.0
# 4      Super built-up  Area                  Kothanur      2 BHK      1200.0
# ...                     ...                       ...        ...         ...
# 13314  Super built-up  Area         Green Glen Layout      3 BHK      1715.0
# 13315        Built-up  Area                Whitefield  5 Bedroom      3453.0
# 13317        Built-up  Area     Raja Rajeshwari Nagar      2 BHK      1141.0
# 13318  Super built-up  Area           Padmanabhanagar      4 BHK      4689.0
# 13319  Super built-up  Area              Doddathoguru      1 BHK       550.0
#
# ...

# %%
df6.price_per_sqft.describe()
# Out:
# count     12013.000000
# mean       6206.082347
# std        3985.518807
# min         267.829813
# 25%        4199.363057
# 50%        5252.525253
# 75%        6823.529412
# max      176470.588235
# Name: price_per_sqft, dtype: float64

# %%
m = np.mean(df6.price_per_sqft)
st = np.std(df6.price_per_sqft)
df7 = df6[(df6.price_per_sqft>(m-st)) & (df6.price_per_sqft<=(m+st))]
df7
# Out:
#                   area_type                  location       size  total_sqft  \
# 0      Super built-up  Area  Electronic City Phase II      2 BHK      1056.0
# 1                Plot  Area          Chikka Tirupathi  4 Bedroom      2600.0
# 2            Built-up  Area               Uttarahalli      3 BHK      1440.0
# 3      Super built-up  Area        Lingadheeranahalli      3 BHK      1521.0
# 4      Super built-up  Area                  Kothanur      2 BHK      1200.0
# ...                     ...                       ...        ...         ...
# 13313  Super built-up  Area               Uttarahalli      3 BHK      1345.0
# 13314  Super built-up  Area         Green Glen Layout      3 BHK      1715.0
# 13315        Built-up  Area                Whitefield  5 Bedroom      3453.0
# 13317        Built-up  Area     Raja Rajeshwari Nagar      2 BHK      1141.0
# 13319  Super built-up  Area              Doddathoguru      1 BHK       550.0
#
# ...

# %%
df7.price_per_sqft.describe()
# Out:
# count    10896.000000
# mean      5321.818765
# std       1611.495600
# min       2222.222222
# 25%       4106.280193
# 50%       5044.323289
# 75%       6303.772462
# max      10169.491525
# Name: price_per_sqft, dtype: float64

# %%
df7['BHK'].value_counts(ascending=False)
# Out:
# 2     5267
# 3     4165
# 4      693
# 1      571
# 5      100
# 6       51
# 7       23
# 8       16
# 9        7
# 11       1
# 13       1
# 10       1
# Name: BHK, dtype: int64

# %%
def plot_scatter_chart(df,location):
    bhk2 = df[(df.location==location) & (df.BHK==2)]
    bhk3 = df[(df.location==location) & (df.BHK==3)]
    matplotlib.rcParams['figure.figsize'] = (15,10)
    plt.scatter(bhk2.total_sqft,bhk2.price,color='blue',label='2 BHK', s=50,marker='+')
    plt.scatter(bhk3.total_sqft,bhk3.price,marker='+', color='green',label='3 BHK', s=50)
    plt.xlabel("Total Square Feet Area")
    plt.ylabel("Price (Lakh Indian Rupees)")
    plt.title(location)
    plt.legend()
    
plot_scatter_chart(df7,"Whitefield")

# %%
plot_scatter_chart(df7,"Sarjapur  Road")

# %%
plot_scatter_chart(df7,"Kanakpura Road")

# %%
plot_scatter_chart(df7,"Thanisandra")

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib
matplotlib.rcParams["figure.figsize"] = (20,10)
plt.hist(df7.price_per_sqft,rwidth=0.8)
plt.xlabel("Price Per Square Feet")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
len(df7)
# Out:
# 10896

# %%
plt.hist(df7.bath,rwidth=0.7)
plt.xlabel("Number of bathrooms")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
len(df7[df7.bath>6])
# Out:
# 50

# %%
df7[df7.bath>df7.BHK+2]
# Out:
#                   area_type       location       size  total_sqft  bath  \
# 2620   Super built-up  Area          other      6 BHK     11338.0   9.0
# 7709         Built-up  Area  Chikkabanavar  4 Bedroom      2460.0   7.0
# 12103  Super built-up  Area    Thanisandra      3 BHK      1806.0   6.0
#
#        balcony   price  BHK  price_per_sqft
# 2620       1.0  1000.0    6     8819.897689
# 7709       2.0    80.0    4     3252.032520
# 12103      2.0   116.0    3     6423.034330

# %%
df8 = df7[df7.bath>df7.BHK+2]
df8.shape
# Out:
# (3, 9)

# %%
df8.drop(df8[df8['bath'] > 5].index, inplace = True)
# Out:
# C:\Users\disha\anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df7
# Out:
#                   area_type                  location       size  total_sqft  \
# 0      Super built-up  Area  Electronic City Phase II      2 BHK      1056.0
# 1                Plot  Area          Chikka Tirupathi  4 Bedroom      2600.0
# 2            Built-up  Area               Uttarahalli      3 BHK      1440.0
# 3      Super built-up  Area        Lingadheeranahalli      3 BHK      1521.0
# 4      Super built-up  Area                  Kothanur      2 BHK      1200.0
# ...                     ...                       ...        ...         ...
# 13313  Super built-up  Area               Uttarahalli      3 BHK      1345.0
# 13314  Super built-up  Area         Green Glen Layout      3 BHK      1715.0
# 13315        Built-up  Area                Whitefield  5 Bedroom      3453.0
# 13317        Built-up  Area     Raja Rajeshwari Nagar      2 BHK      1141.0
# 13319  Super built-up  Area              Doddathoguru      1 BHK       550.0
#
# ...

# %%
len(df7[(df7.bath)>=6])
# Out:
# 154

# %%
df7["location_S.no"] = df7["location"]
df7
# Out:
# C:\Users\disha\AppData\Local\Temp/ipykernel_5008/2463373246.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df7["location_S.no"] = df7["location"]
#                   area_type                  location       size  total_sqft  \
# 0      Super built-up  Area  Electronic City Phase II      2 BHK      1056.0
# 1                Plot  Area          Chikka Tirupathi  4 Bedroom      2600.0
# 2            Built-up  Area               Uttarahalli      3 BHK      1440.0
# 3      Super built-up  Area        Lingadheeranahalli      3 BHK      1521.0
# 4      Super built-up  Area                  Kothanur      2 BHK      1200.0
# ...                     ...                       ...        ...         ...
# ...

# %%
list(df7.columns.values)
# Out:
# ['area_type',
#  'location',
#  'location_S.no',
#  'size',
#  'total_sqft',
#  'bath',
#  'balcony',
#  'price',
#  'BHK',
#  'price_per_sqft']

# %%
df7 = df7[['area_type',
 'location',
 'location_S.no',
 'size',
 'total_sqft',
 'bath',
 'balcony',
 'price',
 'BHK',
 'price_per_sqft']]

# %%
df7
# Out:
#                   area_type                  location  \
# 0      Super built-up  Area  Electronic City Phase II
# 1                Plot  Area          Chikka Tirupathi
# 2            Built-up  Area               Uttarahalli
# 3      Super built-up  Area        Lingadheeranahalli
# 4      Super built-up  Area                  Kothanur
# ...                     ...                       ...
# 13313  Super built-up  Area               Uttarahalli
# 13314  Super built-up  Area         Green Glen Layout
# 13315        Built-up  Area                Whitefield
# 13317        Built-up  Area     Raja Rajeshwari Nagar
# 13319  Super built-up  Area              Doddathoguru
#
#                   location_S.no       size  total_sqft  bath  balcony   price  \
# 0      Electronic City Phase II      2 BHK      1056.0   2.0      1.0   39.07
# 1              Chikka Tirupathi  4 Bedroom      2600.0   5.0      3.0  120.00
# 2                   Uttarahalli      3 BHK      1440.0   2.0      3.0   62.00
# ...

# %%
df7('location_S.no') = df7('location_S.no').cat.codes
# Out:
#   File "C:\Users\disha\AppData\Local\Temp/ipykernel_5008/1172753180.py", line 1
#     df7('location_S.no') = df7('location_S.no').cat.codes
#     ^
# SyntaxError: cannot assign to function call

# %%
df8 = df7.drop('size',axis = 'columns')

# %%
df8
# Out:
#                   area_type                  location  \
# 0      Super built-up  Area  Electronic City Phase II
# 1                Plot  Area          Chikka Tirupathi
# 2            Built-up  Area               Uttarahalli
# 3      Super built-up  Area        Lingadheeranahalli
# 4      Super built-up  Area                  Kothanur
# ...                     ...                       ...
# 13313  Super built-up  Area               Uttarahalli
# 13314  Super built-up  Area         Green Glen Layout
# 13315        Built-up  Area                Whitefield
# 13317        Built-up  Area     Raja Rajeshwari Nagar
# 13319  Super built-up  Area              Doddathoguru
#
#                   location_S.no  total_sqft  bath  balcony   price  BHK  \
# 0      Electronic City Phase II      1056.0   2.0      1.0   39.07    2
# 1              Chikka Tirupathi      2600.0   5.0      3.0  120.00    4
# 2                   Uttarahalli      1440.0   2.0      3.0   62.00    3
# ...

# %%
df8.shape
# Out:
# (10896, 9)

# %%
df8
# Out:
#                   area_type                  location  \
# 0      Super built-up  Area  Electronic City Phase II
# 1                Plot  Area          Chikka Tirupathi
# 2            Built-up  Area               Uttarahalli
# 3      Super built-up  Area        Lingadheeranahalli
# 4      Super built-up  Area                  Kothanur
# ...                     ...                       ...
# 13313  Super built-up  Area               Uttarahalli
# 13314  Super built-up  Area         Green Glen Layout
# 13315        Built-up  Area                Whitefield
# 13317        Built-up  Area     Raja Rajeshwari Nagar
# 13319  Super built-up  Area              Doddathoguru
#
#                   location_S.no  total_sqft  bath  balcony   price  BHK  \
# 0      Electronic City Phase II      1056.0   2.0      1.0   39.07    2
# 1              Chikka Tirupathi      2600.0   5.0      3.0  120.00    4
# 2                   Uttarahalli      1440.0   2.0      3.0   62.00    3
# ...

# %%
df8['location_S.no'] = df8['location_S.no'].astype('category')
df8['location_S.no'] = df8['location_S.no'].cat.codes

# %%
df8['area_type'] = df8['area_type'].astype('category')
df8['area_type'] = df8['area_type'].cat.codes
df8
# Out:
#        area_type                  location  location_S.no  total_sqft  bath  \
# 0              3  Electronic City Phase II             77      1056.0   2.0
# 1              2          Chikka Tirupathi             60      2600.0   5.0
# 2              0               Uttarahalli            221      1440.0   2.0
# 3              3        Lingadheeranahalli            155      1521.0   3.0
# 4              3                  Kothanur            147      1200.0   2.0
# ...          ...                       ...            ...         ...   ...
# 13313          3               Uttarahalli            221      1345.0   2.0
# 13314          3         Green Glen Layout             85      1715.0   3.0
# 13315          0                Whitefield            230      3453.0   4.0
# 13317          0     Raja Rajeshwari Nagar            189      1141.0   2.0
# 13319          3              Doddathoguru             72       550.0   1.0
#
#        balcony   price  BHK  price_per_sqft
# ...

# %%
x = df8.drop(['price','price_per_sqft','location'] , axis = 'columns')
x.head()
# Out:
#    area_type  location_S.no  total_sqft  bath  balcony  BHK
# 0          3             77      1056.0   2.0      1.0    2
# 1          2             60      2600.0   5.0      3.0    4
# 2          0            221      1440.0   2.0      3.0    3
# 3          3            155      1521.0   3.0      1.0    3
# 4          3            147      1200.0   2.0      1.0    2

# %%
y = df8.price
y.head()
# Out:
# 0     39.07
# 1    120.00
# 2     62.00
# 3     95.00
# 4     51.00
# Name: price, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size = 0.001,random_state = 10)

# %%
from sklearn.linear_model import LinearRegression
lr_clf = LinearRegression()
lr_clf.fit(x_train,y_train)
lr_clf.score(x_test,y_test)
# Out:
# 0.9470309356624748

# %% [markdown]
# # LinearRegression accuracy = 94.70%

# %%
lr_clf.predict([[0,221,1440,2,3,3]])
# Out:
# array([68.97505101])

# %%
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score

cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=10)

cross_val_score(LinearRegression(), x, y)
# Out:
# array([0.82817563, 0.7691061 , 0.76494953, 0.79308515, 0.82471075])

# %%
from sklearn.tree import DecisionTreeRegressor
Dt = DecisionTreeRegressor(random_state=20)
Dt.fit(x_train,y_train)
Dt.score(x_test,y_test)
# Out:
# 0.9959417564167659

# %%
    matplotlib.rcParams['figure.figsize'] = (30,90)
    plt.scatter(df8.BHK,df8.price,marker='+', color='green',label='3 BHK', s=100)
    plt.xlabel("Total Square Feet Area")
    plt.ylabel("Price (Lakh Indian Rupees)")
    plt.title(location)
    plt.legend()
    
plot_scatter_chart(df7,"Whitefield")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5008/3941469807.py in <module>
#       3 plt.xlabel("Total Square Feet Area")
#       4 plt.ylabel("Price (Lakh Indian Rupees)")
# ----> 5 plt.title(location)
#       6 plt.legend()
#       7
#
# NameError: name 'location' is not defined

# %%
import pickle
with open('banglore_home_prices_model.pickle','wb') as f:
    pickle.dump(lr_clf,f)

# %%
import json
columns = {
    'df8' : [col.lower() for col in x.columns]
}
with open("columns.json","w") as f:
    f.write(json.dumps(columns))
